# %% [markdown]
# # 1. Introduction
# - Research question
# - Hypothesis
#
# # 2. Data Description
# - Tweet dataset
# - Stock data
# - Time window
#
# # 3. Data Cleaning
# - Return calculation
# - Alignment of dates
#
# # 4. Methodology
# - Event study framework
# - Abnormal return formula
# - Volatility calculation
#
# # 5. Results
# - Short-term impact
# - Long-term impact
# - Industry comparison
#
# # 6. Statistical Testing
# - t-test
# - Significance
#
# # 7. Conclusion
